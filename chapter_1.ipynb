# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavcodes001/learning_pandas/blob/master/chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame({"col1":[1,2,3],"col2":[4,5,6],"col3":[7,8,9]})
display(df)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df = pd.DataFrame([[2,4,6],[8,10,12],[14,16,18]], index = ['x','y','z'], columns = ['col1','col2','col3'])
display(df)
# Out:
#    col1  col2  col3
# x     2     4     6
# y     8    10    12
# z    14    16    18

# %%
df.head(1)
# Out:
#    col1  col2  col3
# x     2     4     6

# %%
df.tail(2)
# Out:
#    col1  col2  col3
# y     8    10    12
# z    14    16    18

# %%
df.nunique()
# Out:
# col1    3
# col2    3
# col3    3
# dtype: int64

# %%
df['col1'].unique()
# Out:
# array([ 2,  8, 14])
